# %% [markdown]
# **Вычисление основных метрик для Индексов и Компаний**

# %%
import pandas as pd
import numpy as np

# %%
# Пути к файлам
file_paths = {
    "IMOEX": "imoex_data_new.csv",
    "MOEXFN": "moexfn_data_2017_2025.csv",
    "OilGas": "oilgas_data_2017_2025.csv",
    "RTSI": "rtsi_data_2017_2025.csv",
    "Gazprom": "gazp_data_2017_2025.csv",
    "Lukoil": "lukoyl_data_2017_2025.csv",
    "Magnit": "magnit_data_2017_2025.csv",
    "Sberbank": "sber_data_2017_2025.csv",
    "Yandex": "yndx_data_2017_2025.csv",
}

# Списки индексов и компаний
index_names = ["IMOEX", "MOEXFN", "OilGas", "RTSI"]
company_names = ["Gazprom", "Lukoil", "Magnit", "Sberbank", "Yandex"]

# %%
# Обработка
def process_data(path, label):
    df = pd.read_csv(path)
    df['date'] = pd.to_datetime(df['begin']) #Приводим к стандартному типу даты
    df.set_index('date', inplace=True)
    df.sort_index(inplace=True)
    df['return'] = np.log(df['close'] / df['close'].shift(1)) #Логарифмическая доходность
    df['volatility_5d'] = df['return'].rolling(window=5).std() #Вычисление скользящего стандартного отклонения 5-ти дневного
    df['label'] = label
    return df[['return', 'volatility_5d', 'value', 'label']].dropna()

# %%
# Объединение
all_indices = []
all_companies = []

for name in index_names:
    df = process_data(file_paths[name], name)
    all_indices.append(df)

for name in company_names:
    df = process_data(file_paths[name], name)
    all_companies.append(df)

# %%
# Комбинированные датафреймы
combined_indices = pd.concat(all_indices)
combined_companies = pd.concat(all_companies)

# %%
# Сохранение
combined_indices.to_csv("combined_indices.csv")
combined_companies.to_csv("combined_companies.csv")

# %%
df=pd.read_csv("combined_indices.csv")

# %%
df.head()
# Out:
#          date    return  volatility_5d         value  label
# 0  2017-01-10  0.011797       0.011468  3.602086e+10  IMOEX
# 1  2017-01-11 -0.008474       0.011363  3.646156e+10  IMOEX
# 2  2017-01-12 -0.002984       0.007531  3.881842e+10  IMOEX
# 3  2017-01-13 -0.007628       0.008141  4.246605e+10  IMOEX
# 4  2017-01-16 -0.002792       0.008148  2.393626e+10  IMOEX

# %%
df['label'].unique()
# Out:
# array(['IMOEX', 'MOEXFN', 'OilGas', 'RTSI'], dtype=object)

# %% [markdown]
# **Категоризации и удаление дубликатов**

# %%
df = pd.read_csv('bbc_news_2017_2025_filtered.csv')

# %%
df['link'].isnull().unique()
# Out:
# array([False])

# %%
import pandas as pd
import re
from urllib.parse import urlparse

df = pd.read_csv('bbc_news_2017_2025_filtered.csv')

df['link_keywords'] = df['link'].apply(lambda x: ' '.join([w for w in re.split(r'[/\-]', urlparse(x).path) if w.isalpha()]))

print(df[['link', 'link_keywords']].head(10))
# Out:
#                                                 link             link_keywords
# 0       http://www.bbc.co.uk/sport/football/38696547            sport football
# 1       http://www.bbc.co.uk/sport/football/38632703            sport football
# 2  http://www.bbc.co.uk/news/world-latin-america-...  news world latin america
# 3         http://www.bbc.co.uk/sport/tennis/38704836              sport tennis
# 4    http://www.bbc.co.uk/news/world-europe-38703914         news world europe
# 5   http://www.bbc.co.uk/sport/horse-racing/38694316        sport horse racing
# 6       http://www.bbc.co.uk/sport/football/38707859            sport football
# 7              http://www.bbc.co.uk/news/uk-38704598                   news uk
# 8  http://www.bbc.co.uk/news/uk-northern-ireland-...  news uk northern ireland
# 9         http://www.bbc.co.uk/sport/tennis/38702928              sport tennis

# %%
len(df['link_keywords'].unique())
# Out:
# 497

# %%
# Сохраняем DataFrame с новым столбцом в новый CSV
df.to_csv('bbc_news_with_keywords.csv', index=False)

# %%
import pandas as pd

# Загружаем данные
df = pd.read_csv("bbc_news_with_keywords.csv")

# Удалим строки с пропущенными значениями
df = df.dropna(subset=["link_keywords"])

# Словарь ключевых слов по категориям
category_keywords = {
    "Спортивные": ["sport", "football", "tennis", "cricket", "rugby", "golf"],
    "Политические": ["politics", "election", "government", "parliament"],
    "Бизнес": ["business", "economy", "company", "market"],
    "Финансовые": ["finance", "bank", "currency", "stock", "trade"],
    "Технологические": ["tech", "technology", "internet", "digital", "ai"],
    "Мировые новости": ["world", "europe", "asia", "africa", "latin-america", "middle-east"],
    "Локальные UK-новости": ["uk", "england", "wales", "scotland", "northern ireland"],
    "Культура и искусство": ["entertainment", "arts", "magazine"],
    "Наука и природа": ["science", "environment"],
    "Здравоохранение": ["health"],
    "Образование": ["education"],
    "Погода и окружающая среда": ["weather"],
    "Медиа и СМИ": ["articles", "videos", "blogs", "newsbeat", "stories"]
}

# Функция категоризации
def categorize(link_keywords):
    tokens = link_keywords.lower().split()
    for category, keywords in category_keywords.items():
        if any(token in keywords for token in tokens):
            return category
    return "Прочее"

# Применяем к DataFrame
df["category"] = df["link_keywords"].apply(categorize)

# %%
df['category'].unique()
# Out:
# array(['Спортивные', 'Мировые новости', 'Локальные UK-новости',
#        'Технологические', 'Образование', 'Прочее', 'Бизнес',
#        'Медиа и СМИ', 'Культура и искусство', 'Наука и природа',
#        'Политические', 'Здравоохранение', 'Погода и окружающая среда'],
#       dtype=object)

# %%
df[df['category'] == 'Образование']
# Out:
#                                                     title published_date  \
# 18       Meet the mum with quadruplet toddlers - BBC News     2017-01-21
# 55      Could tuition fees really cost £54,000? - BBC ...     2017-01-21
# 408     Could tuition fees really cost £54,000? - BBC ...     2017-01-22
# 517     How schools promote pupils' mental wellbeing -...     2017-01-10
# 876     'Pink girly toys don't deter women from engine...     2017-01-27
# ...                                                   ...            ...
# 122414  Rise in school sexism down to phones, says uni...     2024-04-04
# 122532  Rise in school sexism down to phones, says uni...     2024-04-05
# 122954  Children living near Sure Start centres did be...     2024-04-09
# 123495  EHCP: Councils missing education plan deadline...     2024-05-17
# 134076  A-level results: AQA students ‘let down’ by ex...     2024-08-06
#
#                                               description  \
# 18      Meet the mum to quadruplets who went viral aft...
# 55      The headline cost of increased fees might be £...
# 408     The headline cost of increased fees might be £...
# 517     Schools have long been are at the front line w...
# 876     Meet the Sellafield engineer who says playing ...
# ...                                                   ...
# 122414  Teachers fear sexism is on the rise in schools...
# 122532  Teachers fear sexism is on the rise in schools...
# 122954  Children who grew up close to a centre achieve...
# 123495  Many councils in England are failing to meet l...
# 134076  AQA A-level law students were given the wrong ...
#
#                                                 link   link_keywords  \
# 18      http://www.bbc.co.uk/news/education-38690621  news education
# 55      http://www.bbc.co.uk/news/education-38651059  news education
# 408     http://www.bbc.co.uk/news/education-38651059  news education
# 517     http://www.bbc.co.uk/news/education-38571628  news education
# 876     http://www.bbc.co.uk/news/education-38760602  news education
# ...                                              ...             ...
# 122414  http://www.bbc.co.uk/news/education-68731795  news education
# 122532  http://www.bbc.co.uk/news/education-68731795  news education
# 122954  http://www.bbc.co.uk/news/education-68763942  news education
# 123495  http://www.bbc.co.uk/news/education-68668602  news education
# 134076  http://www.bbc.co.uk/news/education-62595349  news education
#
#            category
# 18      Образование
# 55      Образование
# 408     Образование
# 517     Образование
# 876     Образование
# ...             ...
# 122414  Образование
# 122532  Образование
# 122954  Образование
# 123495  Образование
# 134076  Образование
#
# [1367 rows x 6 columns]

# %%
len(df)
# Out:
# 149169

# %%
df.drop_duplicates()
# Out:
#                                                     title published_date  \
# 0       Saido Berahino: Stoke complete deal to sign We...     2017-01-21
# 1       Lawro's Premier League predictions v Split sta...     2017-01-21
# 2       Chapecoense plane: Footballer Neto dreamt of c...     2017-01-21
# 3       Australian Open: Johanna Konta praises support...     2017-01-21
# 4       Friends' 30-year-search for Celtic treasure tr...     2017-01-21
# ...                                                   ...            ...
# 149173  What will anger at sight of gaunt hostages mea...     2025-02-09
# 149174  Kevin Holding: Family of man killed by pop-up ...     2025-02-09
# 149175  Parents suing TikTok over children's deaths sa...     2025-02-09
# 149176  Trump trade war: How Japan shaped Trump's pers...     2025-02-09
# 149177  Strabane: Stephen Holmes dies days after being...     2025-02-09
#
#                                               description  \
# 0       Stoke sign West Brom striker Saido Berahino fo...
# 1       BBC football expert Mark Lawrenson takes on ac...
# 2       Chapecoense football club player Neto is one o...
# 3       Great Britain's Johanna Konta says her family ...
# 4       Two metal detector enthusiasts found a huge ho...
# ...                                                   ...
# 149173  Concerns were raised over the condition of fre...
# 149174  The family of Kevin Holding fear they may neve...
# 149175  Four families who say their children died afte...
# 149176  As a young real estate developer in New York, ...
# 149177  The 31 year old's sister describes him as "eve...
#
#                                                      link  \
# 0            http://www.bbc.co.uk/sport/football/38696547
# 1            http://www.bbc.co.uk/sport/football/38632703
# 2       http://www.bbc.co.uk/news/world-latin-america-...
# 3              http://www.bbc.co.uk/sport/tennis/38704836
# 4         http://www.bbc.co.uk/news/world-europe-38703914
# ...                                                   ...
# 149173    http://www.bbc.co.uk/news/articles/clyz7124dppo
# 149174    http://www.bbc.co.uk/news/articles/cp8q5mpqrvqo
# 149175    http://www.bbc.co.uk/news/articles/c20pyn55v79o
# 149176    http://www.bbc.co.uk/news/articles/c4gp5pw654lo
# 149177    http://www.bbc.co.uk/news/articles/c62q1qz29e7o
#
#                    link_keywords         category
# 0                 sport football       Спортивные
# 1                 sport football       Спортивные
# 2       news world latin america  Мировые новости
# 3                   sport tennis       Спортивные
# 4              news world europe  Мировые новости
# ...                          ...              ...
# 149173             news articles      Медиа и СМИ
# 149174             news articles      Медиа и СМИ
# 149175             news articles      Медиа и СМИ
# 149176             news articles      Медиа и СМИ
# 149177             news articles      Медиа и СМИ
#
# [149169 rows x 6 columns]

# %%
df["published_date"] = pd.to_datetime(df["published_date"])  # преобразуем в формат даты
df = df.sort_values(by="published_date")  # сортировка по возрастанию
df = df.reset_index(drop=True)

# %%
df.head()
# Out:
#                                                title published_date  \
# 0  Manu Tuilagi out of England training camp afte...     2017-01-01
# 1  'Hollywood' sign changed to 'Hollyweed' in new...     2017-01-01
# 2  How are Australia's Syrian refugees coping? - ...     2017-01-01
# 3  How a dead gorilla became the meme of 2016 - B...     2017-01-01
# 4                   Reflections on Africa - BBC News     2017-01-01
#
#                                          description  \
# 0  Manu Tuilagi is withdrawn from England's two-d...
# 1  A prankster changes the world-famous Hollywood...
# 2  Australia has so far resettled about half of t...
# 3  After Harambe was shot in a sad incident in Ci...
# 4  The BBC's Southern Africa correspondent looks ...
#
#                                                 link         link_keywords  \
# 0    http://www.bbc.co.uk/sport/rugby-union/38485970     sport rugby union
# 1  http://www.bbc.co.uk/news/world-us-canada-3848...  news world us canada
# 2  http://www.bbc.co.uk/news/world-australia-3830...  news world australia
# 3  http://www.bbc.co.uk/news/blogs-trending-38383126   news blogs trending
# 4    http://www.bbc.co.uk/news/world-africa-38393661     news world africa
#
#           category
# 0       Спортивные
# 1  Мировые новости
# 2  Мировые новости
# 3      Медиа и СМИ
# 4  Мировые новости

# %%
df[df['category'] == 'Образование']
# Out:
#                                                     title published_date  \
# 543     How schools promote pupils' mental wellbeing -...     2017-01-10
# 642     Oxford academics warning of Brexit 'disaster' ...     2017-01-11
# 650     How schools promote pupils' mental wellbeing -...     2017-01-11
# 721     What does post-truth mean for a philosopher? -...     2017-01-12
# 1229     Meet the mum with quadruplet toddlers - BBC News     2017-01-20
# ...                                                   ...            ...
# 122302  Childcare shortage worsens as costs rise – rep...     2024-04-19
# 122306  DfE says 85,000 more free childcare places nee...     2024-04-19
# 122796  Childcare shortage worsens as costs rise – rep...     2024-04-24
# 124043  EHCP: Councils missing education plan deadline...     2024-05-17
# 131823  A-level results: AQA students ‘let down’ by ex...     2024-08-06
#
#                                               description  \
# 543     Schools have long been are at the front line w...
# 642     A "hard Brexit" would be the "biggest disaster...
# 650     Schools have long been are at the front line w...
# 721     How are philosophers meant to make sense of th...
# 1229    Meet the mum to quadruplets who went viral aft...
# ...                                                   ...
# 122302  Fewer than a third of councils in all areas ha...
# 122306  The Department for Education estimates about 4...
# 122796  Fewer than a third of councils in all areas ha...
# 124043  Many councils in England are failing to meet l...
# 131823  AQA A-level law students were given the wrong ...
#
#                                                 link   link_keywords  \
# 543     http://www.bbc.co.uk/news/education-38571628  news education
# 642     http://www.bbc.co.uk/news/education-38587765  news education
# 650     http://www.bbc.co.uk/news/education-38571628  news education
# 721     http://www.bbc.co.uk/news/education-38557838  news education
# 1229    http://www.bbc.co.uk/news/education-38690621  news education
# ...                                              ...             ...
# 122302  http://www.bbc.co.uk/news/education-68580918  news education
# 122306  http://www.bbc.co.uk/news/education-68848936  news education
# 122796  http://www.bbc.co.uk/news/education-68580918  news education
# 124043  http://www.bbc.co.uk/news/education-68668602  news education
# 131823  http://www.bbc.co.uk/news/education-62595349  news education
#
#            category
# 543     Образование
# 642     Образование
# 650     Образование
# 721     Образование
# 1229    Образование
# ...             ...
# 122302  Образование
# 122306  Образование
# 122796  Образование
# 124043  Образование
# 131823  Образование
#
# [1367 rows x 6 columns]

# %%
df_drop = df.drop_duplicates(subset=["title"]).reset_index(drop=True)

# %%
df_drop
# Out:
#                                                     title published_date  \
# 0       Manu Tuilagi out of England training camp afte...     2017-01-01
# 1       'Hollywood' sign changed to 'Hollyweed' in new...     2017-01-01
# 2       How are Australia's Syrian refugees coping? - ...     2017-01-01
# 3       How a dead gorilla became the meme of 2016 - B...     2017-01-01
# 4                        Reflections on Africa - BBC News     2017-01-01
# ...                                                   ...            ...
# 104718  Manchester United: Andre Onana analysis after ...     2025-02-27
# 104719  Emma Raducanu will play Indian Wells after Dub...     2025-02-27
# 104720  The Today Podcast - What will Starmer’s defenc...     2025-02-27
# 104721  Andrew Tate and brother Tristan arrive in US a...     2025-02-27
# 104722  Ban degrading and violent online pornography, ...     2025-02-27
#
#                                               description  \
# 0       Manu Tuilagi is withdrawn from England's two-d...
# 1       A prankster changes the world-famous Hollywood...
# 2       Australia has so far resettled about half of t...
# 3       After Harambe was shot in a sad incident in Ci...
# 4       The BBC's Southern Africa correspondent looks ...
# ...                                                   ...
# 104718  Manchester United's Andre Onana is in the spot...
# 104719  Britain's Emma Raducanu will travel to the WTA...
# 104720  Plus: Amol & Nick talk tactics over PM-Preside...
# 104721  The pair, facing trial for human trafficking, ...
# 104722  A government-commissioned review will call for...
#
#                                                      link  \
# 0         http://www.bbc.co.uk/sport/rugby-union/38485970
# 1       http://www.bbc.co.uk/news/world-us-canada-3848...
# 2       http://www.bbc.co.uk/news/world-australia-3830...
# 3       http://www.bbc.co.uk/news/blogs-trending-38383126
# 4         http://www.bbc.co.uk/news/world-africa-38393661
# ...                                                   ...
# 104718  http://www.bbc.co.uk/sport/football/articles/c...
# 104719  http://www.bbc.co.uk/sport/tennis/articles/cy5...
# 104720          http://www.bbc.co.uk/sounds/play/m0028bpw
# 104721    http://www.bbc.co.uk/news/articles/cpq222rqv4po
# 104722    http://www.bbc.co.uk/news/articles/c0q1wx3nzy9o
#
#                   link_keywords         category
# 0             sport rugby union       Спортивные
# 1          news world us canada  Мировые новости
# 2          news world australia  Мировые новости
# 3           news blogs trending      Медиа и СМИ
# 4             news world africa  Мировые новости
# ...                         ...              ...
# 104718  sport football articles       Спортивные
# 104719    sport tennis articles       Спортивные
# 104720              sounds play           Прочее
# 104721            news articles      Медиа и СМИ
# 104722            news articles      Медиа и СМИ
#
# [104723 rows x 6 columns]

# %%
len(df_drop)
# Out:
# 104723

# %%
# Сохраняем в новый CSV (опционально)
df_drop.to_csv("bbc_news_categorized.csv", index=False)

# %% [markdown]
# **Сентимент**

# %%
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk

# Загрузка лексикона VADER
nltk.download("vader_lexicon")

# Загружаем данные
df = pd.read_csv("bbc_news_categorized.csv")

# Объединяем title + description
df["text"] = (df["title"] + " " + df["description"]).fillna("")

# Инициализируем анализатор
sid = SentimentIntensityAnalyzer()

# Функция для извлечения compound-оценки
def get_sentiment_scores(text):
    return sid.polarity_scores(text)
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/narciss/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Применяем VADER к тексту
df["sentiment_scores"] = df["text"].apply(get_sentiment_scores)

# Распаковка словаря с оценками в отдельные столбцы
df = pd.concat([df, df["sentiment_scores"].apply(pd.Series)], axis=1)

# %%
# Категория по compound
def categorize_sentiment(compound):
    # Используем значения для compaund по базовым параметрам VADER
    if compound >= 0.05:
        return "positive"
    elif compound <= -0.05:
        return "negative"
    else:
        return "neutral"

df["Sentiment"] = df["compound"].apply(categorize_sentiment)

# %%
# Сохраняем результат
df.to_csv("bbc_news_with_sentiment_and_categorized.csv", index=False)

# %% [markdown]
# **Объединяем данные для удобства дальнейшего исследования**

# %%
import pandas as pd

# Загружаем файл с новостями
df = pd.read_csv("bbc_news_with_sentiment_and_categorized.csv")

# Приводим дату к нужному формату
df["published_date"] = pd.to_datetime(df["published_date"])

# Считаем количество новостей по Sentiment (positive, neutral, negative) 
sentiment_counts = df.groupby(["published_date", "Sentiment"]).size().unstack(fill_value=0)
sentiment_counts.columns = [f"count_{col}" for col in sentiment_counts.columns]

# Средний compound по дню
compound_mean = df.groupby("published_date")["compound"].mean().rename("compound_mean")

# Определим преобладающий сентимент по compound_mean
def get_dominant(compound):
    if compound >= 0.05:
        return "positive"
    elif compound <= -0.05:
        return "negative"
    else:
        return "neutral"

dominant_sentiment = compound_mean.apply(get_dominant).rename("dominant_sentiment")

# Считаем количество новостей по тематическим категориям 
category_counts = df.groupby(["published_date", "category"]).size().unstack(fill_value=0)
category_counts.columns = [f"count_{col}" for col in category_counts.columns]

# Общее количество новостей в день
total_counts = df.groupby("published_date").size().rename("total_news")

# Объединяем всё по дате 
df_summary = pd.concat([sentiment_counts,dominant_sentiment, category_counts, total_counts], axis=1).reset_index()

# %%
df_summary.head()
# Out:
#   published_date  count_negative  count_neutral  count_positive  \
# 0     2017-01-01              12             10              22
# 1     2017-01-02              10              9              18
# 2     2017-01-03              16             16              14
# 3     2017-01-04              21              4              13
# 4     2017-01-05              21             17              16
#
#   dominant_sentiment  count_Бизнес  count_Здравоохранение  \
# 0           positive             1                      1
# 1           positive             1                      0
# 2            neutral             5                      0
# 3           negative             3                      1
# 4           negative             3                      0
#
#    count_Культура и искусство  count_Локальные UK-новости  count_Медиа и СМИ  \
# 0                           6                           8                  3
# 1                           4                           4                  2
# 2                           6                           7                  1
# 3                           2                           4                  2
# 4                           1                           9                  2
#
#    count_Мировые новости  count_Наука и природа  count_Образование  \
# 0                      8                      0                  0
# 1                      8                      0                  0
# 2                      6                      1                  0
# 3                     11                      0                  0
# 4                     13                      0                  0
#
#    count_Погода и окружающая среда  count_Политические  count_Прочее  \
# 0                                0                   0             2
# 1                                0                   4             0
# 2                                0                   1             1
# 3                                0                   1             1
# 4                                0                   2             2
#
#    count_Спортивные  count_Технологические  total_news
# 0                15                      0          44
# 1                13                      1          37
# 2                17                      1          46
# 3                12                      1          38
# 4                15                      7          54

# %%
# Сохраняем в файл
df_summary.to_csv("news_summary_dayly.csv", index=False)

# %%
len(df_summary)
# Out:
# 2609

# %%
df_summary.tail()
# Out:
#      published_date  count_negative  count_neutral  count_positive  \
# 2604     2025-02-23              22              6              25
# 2605     2025-02-24              37             12              18
# 2606     2025-02-25              37              7              21
# 2607     2025-02-26              38             11              21
# 2608     2025-02-27              28             10              22
#
#       count_Бизнес  count_Здравоохранение  count_Культура и искусство  \
# 2604             0                      0                           0
# 2605             0                      0                           0
# 2606             0                      0                           0
# 2607             0                      0                           0
# 2608             0                      0                           0
#
#       count_Локальные UK-новости  count_Медиа и СМИ  count_Мировые новости  \
# 2604                           0                 41                      0
# 2605                           0                 52                      0
# 2606                           0                 49                      0
# 2607                           0                 51                      0
# 2608                           0                 42                      0
#
#       count_Наука и природа  count_Образование  \
# 2604                      0                  0
# 2605                      0                  0
# 2606                      0                  0
# 2607                      0                  0
# 2608                      0                  0
#
#       count_Погода и окружающая среда  count_Политические  count_Прочее  \
# 2604                                0                   0             1
# 2605                                0                   0             6
# 2606                                0                   0             3
# 2607                                0                   0             3
# 2608                                0                   0             6
#
#       count_Спортивные  count_Технологические  total_news
# 2604                11                      0          53
# 2605                 9                      0          67
# 2606                13                      0          65
# 2607                16                      0          70
# 2608                12                      0          60

# %%
df_summary
# Out:
#      published_date  count_negative  count_neutral  count_positive  \
# 0        2017-01-01              12             10              22
# 1        2017-01-02              10              9              18
# 2        2017-01-03              16             16              14
# 3        2017-01-04              21              4              13
# 4        2017-01-05              21             17              16
# ...             ...             ...            ...             ...
# 2604     2025-02-23              22              6              25
# 2605     2025-02-24              37             12              18
# 2606     2025-02-25              37              7              21
# 2607     2025-02-26              38             11              21
# 2608     2025-02-27              28             10              22
#
#      dominant_sentiment  count_Бизнес  count_Здравоохранение  \
# 0              positive             1                      1
# 1              positive             1                      0
# 2               neutral             5                      0
# 3              negative             3                      1
# 4              negative             3                      0
# ...                 ...           ...                    ...
# 2604            neutral             0                      0
# 2605           negative             0                      0
# 2606           negative             0                      0
# 2607           negative             0                      0
# 2608           negative             0                      0
#
#       count_Культура и искусство  count_Локальные UK-новости  \
# 0                              6                           8
# 1                              4                           4
# 2                              6                           7
# 3                              2                           4
# 4                              1                           9
# ...                          ...                         ...
# 2604                           0                           0
# 2605                           0                           0
# 2606                           0                           0
# 2607                           0                           0
# 2608                           0                           0
#
#       count_Медиа и СМИ  count_Мировые новости  count_Наука и природа  \
# 0                     3                      8                      0
# 1                     2                      8                      0
# 2                     1                      6                      1
# 3                     2                     11                      0
# 4                     2                     13                      0
# ...                 ...                    ...                    ...
# 2604                 41                      0                      0
# 2605                 52                      0                      0
# 2606                 49                      0                      0
# 2607                 51                      0                      0
# 2608                 42                      0                      0
#
#       count_Образование  count_Погода и окружающая среда  count_Политические  \
# 0                     0                                0                   0
# 1                     0                                0                   4
# 2                     0                                0                   1
# 3                     0                                0                   1
# 4                     0                                0                   2
# ...                 ...                              ...                 ...
# 2604                  0                                0                   0
# 2605                  0                                0                   0
# 2606                  0                                0                   0
# 2607                  0                                0                   0
# 2608                  0                                0                   0
#
#       count_Прочее  count_Спортивные  count_Технологические  total_news
# 0                2                15                      0          44
# 1                0                13                      1          37
# 2                1                17                      1          46
# 3                1                12                      1          38
# 4                2                15                      7          54
# ...            ...               ...                    ...         ...
# 2604             1                11                      0          53
# 2605             6                 9                      0          67
# 2606             3                13                      0          65
# 2607             3                16                      0          70
# 2608             6                12                      0          60
#
# [2609 rows x 19 columns]
